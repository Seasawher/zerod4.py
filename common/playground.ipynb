# %%
import sys
sys.path.append('..')

import common.gridworld as gw

env = gw.GridWorld()
env.render_v()

# %%
import numpy as np

env = gw.GridWorld()
V = {}
for state in env.states():
    V[state] = np.random.randn()
env.render_v(V)
